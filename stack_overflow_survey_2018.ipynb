# %% [markdown]
# # TASK 1

# %% [markdown]
# A) Import all the required libraries

# %%
import pandas as pd 
import numpy as np
from pandas import Series

import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns 
color = sns.color_palette()

from numpy import array

import warnings
warnings.filterwarnings("ignore")



pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# B) Access the Dataset as pandas Dataframes

# %%
#df_schema – contains the data from the schema file
#df_survey – contains the data for the survey

schema = pd.read_csv('survey_results_schema.csv')
stack_data = pd.read_csv('survey_results_public.csv')

df_schema = pd.DataFrame(schema)
df_survey = pd.DataFrame(stack_data)

# %%
df_schema
# Out:
#                           Column  \
# 0                     Respondent
# 1                          Hobby
# 2                     OpenSource
# 3                        Country
# 4                        Student
# 5                     Employment
# 6                FormalEducation
# 7                 UndergradMajor
# 8                    CompanySize
# 9                        DevType
# 10                   YearsCoding
# 11               YearsCodingProf
# 12               JobSatisfaction
# 13            CareerSatisfaction
# 14                 HopeFiveYears
# 15               JobSearchStatus
# 16                    LastNewJob
# 17                    AssessJob1
# 18                    AssessJob2
# 19                    AssessJob3
# 20                    AssessJob4
# 21                    AssessJob5
# 22                    AssessJob6
# 23                    AssessJob7
# 24                    AssessJob8
# 25                    AssessJob9
# 26                   AssessJob10
# ...

# %%
df_survey.head()
# Out:
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# ...

# %% [markdown]
# C) Explore the df_schema to see what are different columns available and see their description

# %%
pd.options.display.max_colwidth = 300
df_schema
# Out:
#                           Column  \
# 0                     Respondent
# 1                          Hobby
# 2                     OpenSource
# 3                        Country
# 4                        Student
# 5                     Employment
# 6                FormalEducation
# 7                 UndergradMajor
# 8                    CompanySize
# 9                        DevType
# 10                   YearsCoding
# 11               YearsCodingProf
# 12               JobSatisfaction
# 13            CareerSatisfaction
# 14                 HopeFiveYears
# 15               JobSearchStatus
# 16                    LastNewJob
# 17                    AssessJob1
# 18                    AssessJob2
# 19                    AssessJob3
# 20                    AssessJob4
# 21                    AssessJob5
# 22                    AssessJob6
# 23                    AssessJob7
# 24                    AssessJob8
# 25                    AssessJob9
# 26                   AssessJob10
# ...

# %%
df_survey.iloc[0:5,0:10]

# These 10 columns ( Respondent Hobby OpenSource Country Student Employment FormalEducation UndergradMajor CompanySize DevType )
# shows the basic necessary information about the developers
# we have taken only first 5 rows,  As Dataset is very big.
# Out:
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                         FormalEducation  \
# 0  Employed part-time                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                        Associate degree
# 3  Employed full-time                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning a degree
#
#                                                     UndergradMajor  \
# ...

# %% [markdown]
# D) Find out how many users took the survey and how many parameters have been stored corresponding to each user?

# %%
print("Number of users took the survey = Size of data", df_survey.shape)

#Here number of users who took the the survey is 98855 and ther are 129 parameters corresponding to each user
# Out:
# Number of users took the survey = Size of data (98855, 129)

# %% [markdown]
# E) Analyze the df_survey dataframe and see what kind of Data is available, its type, and its values for different users

# %%
df_survey.dtypes
# Out:
# Respondent                       int64
# Hobby                           object
# OpenSource                      object
# Country                         object
# Student                         object
# Employment                      object
# FormalEducation                 object
# UndergradMajor                  object
# CompanySize                     object
# DevType                         object
# YearsCoding                     object
# YearsCodingProf                 object
# JobSatisfaction                 object
# CareerSatisfaction              object
# HopeFiveYears                   object
# JobSearchStatus                 object
# LastNewJob                      object
# AssessJob1                     float64
# AssessJob2                     float64
# AssessJob3                     float64
# AssessJob4                     float64
# AssessJob5                     float64
# AssessJob6                     float64
# AssessJob7                     float64
# ...

# %% [markdown]
# # TASK 2

# %% [markdown]
# A) What is the data type of ConvertedSalary column? Does it contain categoric or numeric data?

# %%
df_survey.ConvertedSalary.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ConvertedSalary is numeric type

# %% [markdown]
# B) What does ConvertedSalary column store?

# %% [markdown]
# ConvertedSalary column stores the salary of developers converted into  US Dollar

# %%
# C) Write code to Verify whether the ConvertedSalary column contains any null value or not

df_survey['ConvertedSalary'].isnull().any()

# Yes it contains NUll values
# Out:
# True

# %% [markdown]
# D) Based on the output of part C), remove the rows containing Null values in a separate Dataframe called df_sal_NonNa

# %%
df_sal_NonNa = df_survey.dropna(axis=0, subset=['ConvertedSalary'])

# %%
df_sal_NonNa.head()
# Out:
#    Respondent Hobby OpenSource         Country         Student  \
# 1           3   Yes        Yes  United Kingdom              No
# 4           7   Yes         No    South Africa  Yes, part-time
# 5           8   Yes         No  United Kingdom              No
# 6           9   Yes        Yes   United States              No
# 8          11   Yes        Yes   United States              No
#
#            Employment                                         FormalEducation  \
# 1  Employed full-time                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning a degree
# 5  Employed full-time                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6  Employed full-time  Some college/university study without earning a degree
# 8  Employed full-time  Some college/university study without earning a degree
#
#                                                          UndergradMajor  \
# ...

# %% [markdown]
# E). Use seaborn library to plot histogram for non-null values of ConvertedSalary column

# %%
sns.distplot(df_sal_NonNa['ConvertedSalary'],kde = False,bins =30)
sns.distplot(df_sal_NonNa['ConvertedSalary'],kde = False,bins =500)
plt.show()

#This plot contains Plot histogram for df_sal_NonNa having bin size as 30 and 500
# Blue one is with binsize 500 and brown is for binsize 30

# %% [markdown]
# F). Create a new Dataframe variable called df_sal_low, to store non-null ConvertedSalary whose value is less than or equal to 250000.

# %%
df_sal_low = df_sal_NonNa[df_sal_NonNa['ConvertedSalary'] <= 250000]

# %%
sns.distplot(df_sal_low['ConvertedSalary'], kde=False)

#this plot shows the salary of all developers who have their converted less than or equal to 250000

# %% [markdown]
# G) Plot Salary distribution for both df_sal_NonNa and df_sal_low using a KDE Plot

# %%
sns.distplot(df_sal_NonNa['ConvertedSalary'],kde = True,bins = 30)
sns.distplot(df_sal_low['ConvertedSalary'], kde=True,bins = 30)


#kernel density estimation is a non-parametric way to estimate the probability density function of a random variable.
#this graph shows a kde plot for df_sal_NonNa( No empty value in ConvertedSalary) and df_sal_low( ConvertedSalary less than or equal to 25000)

# %% [markdown]
# # TASK 3

# %% [markdown]
# A). Plot stripplot keeping ConvertedSalary on the Y-axis and developers' countries on the X-axis. Use df_sal_NonNa

# %%
sns.stripplot(x='Country', y='ConvertedSalary', data=df_sal_NonNa)

# %% [markdown]
# Congo has the lowest salary
# united states has the highest salary

# %% [markdown]
# B) The plot in section A is not very clear in order to make predictions. So we need to select some countries. Lets take the top 5 countries from where the users’ belong to see their salary distribution. Again plot the stripplot using convertedsalary for the top 5 countries.

# %%
d1 = df_sal_NonNa['Country'].value_counts().reset_index().head(5)

# %%
sns.stripplot(x=d1['index'], y='ConvertedSalary', data=df_sal_NonNa)

# %%
d1
#  most developers who took the survey belongs to UNITED STATES
# Out:
#             index  Country
# 0   United States    12941
# 1           India     4091
# 2  United Kingdom     3794
# 3         Germany     3362
# 4          Canada     1983

# %% [markdown]
# C) Plot the swarmplot for the top 5 countries based on no. of developers for the Salary. (refer above section B for Data)

# %%
sns.swarmplot(x = d1['index'], y = 'ConvertedSalary', data = df_sal_NonNa)


# SwarmPlot is comparatively slower than stripplot that is why we have used only 5 values

# %% [markdown]
# # TASK 4

# %% [markdown]
# A) See how Formal Education is related to Salary by displaying in the form of swarmplot

# %%
sns.swarmplot(x = 'FormalEducation', y = 'ConvertedSalary', data = df_sal_NonNa.head(10))

# %% [markdown]
# B) Next add Employment as third or the hue parameter to see how Formal Education is scattered in terms of Employment Type

# %%
sns.swarmplot(x = 'FormalEducation', y = 'ConvertedSalary',hue = 'Employment', data = df_sal_NonNa.head(10))

# hue parameter determines which column in the data frame should be used for colour encoding. Here employement column determines color

# %% [markdown]
# # TYPE 5

# %% [markdown]
# Lets now create a boxplot using 'Formal Education and 'Converted Salary'

# %%
sns.boxplot(x="FormalEducation", y="ConvertedSalary", data=df_sal_NonNa.head(10))
    
# We see that more developers are in the range of 50000 t0 150000

# %% [markdown]
# # TYPE 6

# %% [markdown]
# A) Create a Pie chart to display the distribution of developers based on their Formal Education

# %%
count_formal =df_sal_NonNa["FormalEducation"].value_counts()

# %%
count_formal
# Out:
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              22824
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           11179
# Some college/university study without earning a degree                                 6103
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     3021
# Associate degree                                                                       1513
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              1191
# Professional degree (JD, MD, etc.)                                                      612
# Primary/elementary school                                                               388
# I never completed any formal education                                                  177
# Name: FormalEducation, dtype: int64

# %%
# Data to plot
labels = ['Bachelor’s degree','Master’s degree','college/university study without earning a degree','Secondary school','Associate degree','Other doctoral degree','Professional degree','Primary school','I never completed any formal education']

sizes = [22824,11179,6103,3021,1513,1191,612,388,177]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','blue','green','yellow','magenta']
 
# Plot
plt.pie(sizes, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %% [markdown]
# B )Explode the three segments with lowest values Pass in a custom set of colors for different segments

# %%
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','blue','green','yellow','magenta']
explode = (0, 0, 0, 0, 0, 0, 0.1, 0.1, 0.1)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()
